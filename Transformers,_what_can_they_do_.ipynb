# %% [markdown]
# # Transformers, what can they do?

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
# !pip install datasets evaluate "transformers[sentencepiece]"
# Out:
# Requirement already satisfied: datasets in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (4.1.1)
# Requirement already satisfied: evaluate in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (0.4.6)
# Requirement already satisfied: transformers[sentencepiece] in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (4.56.2)
# Requirement already satisfied: filelock in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from datasets) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2025.9.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from datasets) (0.35.3)
# Requirement already satisfied: packaging in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: regex!=2019.12.17 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from transformers[sentencepiece]) (2025.9.18)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from transformers[sentencepiece]) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from transformers[sentencepiece]) (0.6.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from transformers[sentencepiece]) (0.2.1)
# Requirement already satisfied: protobuf in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from transformers[sentencepiece]) (6.32.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from huggingface-hub>=0.24.0->datasets) (1.1.10)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/myproject/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0
# [{'label': 'POSITIVE', 'score': 0.9598048329353333}]

# %%
classifier(
    ["I've been waiting for a HuggingFace course my whole life.", "I hate this so much!"]
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598048329353333},
#  {'label': 'NEGATIVE', 'score': 0.9994558691978455}]

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification")
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445964455604553, 0.11197598278522491, 0.04342750459909439]}

# %%
from transformers import pipeline

generator = pipeline("text-generation")
generator("In this course, we will teach you how to")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course, we will teach you how to build your own custom software to support all kinds of scenarios, from game play to the development of your own systems. In other words, we will show you how you use your own system for your projects, and how you can build them on your own.\n\nThe course will cover a variety of topics. We will also cover the different ways in which you can use your technology, how to create custom applications, how to use the cloud, and how to use the online services.\n\nThis course is designed to be a fun and interactive experience. It is designed for students who have had a lot of fun with their own systems. We will teach you to build your own custom applications using your own hardware, and also to use your own software on your own system to create some pretty awesome features!\n\nIn this course, we will provide you with a great amount of information about the software you develop. We will also show you how to use your system for some of the most popular games.\n\nThe course will cover the following topics:\n\nCreating custom applications for the cloud\n\nCreating custom applications for the online services\n\nCreating custom applications for game play\n\nCreating custom applications for the networking services\n\nCreating custom applications for the web servers\n\n'}]

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="distilgpt2")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# Device set to use mps:0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "In this course, we will teach you how to apply your skills to the skills and skills of the world's most powerful and talented individuals. We will also show you how to apply your skills to the skills and skills of the world's most powerful and talented individuals.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"},
#  {'generated_text': 'In this course, we will teach you how to navigate with the best of software, from tools to information about web developers.\n\n\n\n\nThe course covers some of the challenges you will need to overcome in this course.\nIn the course, we will teach you how to navigate with the best of software, from tools to information about web developers.\nWe will teach you how to navigate with the best of software, from tools to information about web developers.\nIntroduction\nIn this course, we will teach you how to navigate with the best of software, from tools to information about web developers.\nIn this course, we will teach you how to navigate with the best of software, from tools to information about web developers.\nIn this course, we will teach you how to navigate with the best of software, from tools to information about web developers.\nIn this course, we will teach you how to navigate with the best of software, from tools to information about web developers.\nIn this course, we will teach you how to navigate with the best of software, from tools to information about web developers.\nIn this course, we will teach you how to navigate with the best of software, from tools to information about web developers.'}]

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask")
unmasker("This course will teach you all about <mask> models.", top_k=2)
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8 (https://huggingface.co/distilbert/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at distilbert/distilroberta-base were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use mps:0
# [{'score': 0.19619809091091156,
#   'token': 30412,
#   'token_str': ' mathematical',
#   'sequence': 'This course will teach you all about mathematical models.'},
#  {'score': 0.04052705317735672,
#   'token': 38163,
#   'token_str': ' computational',
#   'sequence': 'This course will teach you all about computational models.'}]

# %%
from transformers import pipeline

ner = pipeline("ner", grouped_entities=True)
ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496 (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use mps:0
# [{'entity_group': 'PER',
#   'score': np.float32(0.9981694),
#   'word': 'Sylvain',
#   'start': 11,
#   'end': 18},
#  {'entity_group': 'ORG',
#   'score': np.float32(0.9796019),
#   'word': 'Hugging Face',
#   'start': 33,
#   'end': 45},
#  {'entity_group': 'LOC',
#   'score': np.float32(0.9932106),
#   'word': 'Brooklyn',
#   'start': 49,
#   'end': 57}]

# %%
from transformers import pipeline

question_answerer = pipeline("question-answering")
question_answerer(
    question="Where do I work?",
    context="My name is Sylvain and I work at Hugging Face in Brooklyn",
)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0
# {'score': 0.6949752569198608, 'start': 33, 'end': 45, 'answer': 'Hugging Face'}

# %%
from transformers import pipeline

summarizer = pipeline("summarization")
summarizer(
    """
    America has changed dramatically during recent years. Not only has the number of
    graduates in traditional engineering disciplines such as mechanical, civil,
    electrical, chemical, and aeronautical engineering declined, but in most of
    the premier American universities engineering curricula now concentrate on
    and encourage largely the study of engineering science. As a result, there
    are declining offerings in engineering subjects dealing with infrastructure,
    the environment, and related issues, and greater concentration on high
    technology subjects, largely supporting increasingly complex scientific
    developments. While the latter is important, it should not be at the expense
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other
    industrial countries in Europe and Asia, continue to encourage and advance
    the teaching of engineering. Both China and India, respectively, graduate
    six and eight times as many traditional engineers as does the United States.
    Other industrial countries at minimum maintain their output, while America
    suffers an increasingly serious decline in the number of engineering graduates
    and a lack of well-educated engineers.
"""
)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 3
#       1 from transformers import pipeline
# ----> 3 summarizer = pipeline("summarization")
#       4 summarizer(
#       5     """
#       6     America has changed dramatically during recent years. Not only has the number of
#    (...)     24 """
#      25 )
#
# File /opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/pipelines/__init__.py:1028, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1026 if isinstance(model, str) or framework is None:
#    1027     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# -> 1028     framework, model = infer_framework_load_model(
#    1029         adapter_path if adapter_path is not None else model,
#    1030         model_classes=model_classes,
#    1031         config=config,
#    1032         framework=framework,
#    1033         task=task,
#    1034         **hub_kwargs,
#    1035         **model_kwargs,
#    1036     )
#    1038 hub_kwargs["_commit_hash"] = model.config._commit_hash
#    1040 # Check which preprocessing classes the pipeline uses
#    1041 # None values indicate optional classes that the pipeline can run without, we don't raise errors if loading fails
#
# File /opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/pipelines/base.py:333, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     331         for class_name, trace in all_traceback.items():
#     332             error += f"while loading with {class_name}, an error is thrown:\n{trace}\n"
# --> 333         raise ValueError(
#     334             f"Could not load model {model} with any of the following classes: {class_tuple}. See the original errors:\n\n{error}\n"
#     335         )
#     337 if framework is None:
#     338     framework = infer_framework(model.__class__)
#
# ValueError: Could not load model sshleifer/distilbart-cnn-12-6 with any of the following classes: (<class 'transformers.models.auto.modeling_auto.AutoModelForSeq2SeqLM'>, <class 'transformers.models.bart.modeling_bart.BartForConditionalGeneration'>). See the original errors:
#
# while loading with AutoModelForSeq2SeqLM, an error is thrown:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/pipelines/base.py", line 293, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/models/auto/auto_factory.py", line 604, in from_pretrained
#     return model_class.from_pretrained(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 288, in _wrapper
#     return func(*args, **kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 5097, in from_pretrained
#     config, dtype, dtype_orig = _get_dtype(
#                                 ~~~~~~~~~~^
#         cls, dtype, checkpoint_files, config, sharded_metadata, state_dict, weights_only
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 1358, in _get_dtype
#     state_dict = load_state_dict(
#         checkpoint_files[0], map_location="meta", weights_only=weights_only
#     )
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 532, in load_state_dict
#     check_torch_load_is_safe()
#     ~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/utils/import_utils.py", line 1632, in check_torch_load_is_safe
#     raise ValueError(
#     ...<4 lines>...
#     )
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/pipelines/base.py", line 311, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **fp32_kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/models/auto/auto_factory.py", line 604, in from_pretrained
#     return model_class.from_pretrained(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 288, in _wrapper
#     return func(*args, **kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 5179, in from_pretrained
#     ) = cls._load_pretrained_model(
#         ~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         model,
#         ^^^^^^
#     ...<13 lines>...
#         weights_only=weights_only,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 5445, in _load_pretrained_model
#     load_state_dict(checkpoint_files[0], map_location="meta", weights_only=weights_only).keys()
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 532, in load_state_dict
#     check_torch_load_is_safe()
#     ~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/utils/import_utils.py", line 1632, in check_torch_load_is_safe
#     raise ValueError(
#     ...<4 lines>...
#     )
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
#
# while loading with BartForConditionalGeneration, an error is thrown:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/pipelines/base.py", line 293, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 288, in _wrapper
#     return func(*args, **kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 5097, in from_pretrained
#     config, dtype, dtype_orig = _get_dtype(
#                                 ~~~~~~~~~~^
#         cls, dtype, checkpoint_files, config, sharded_metadata, state_dict, weights_only
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 1358, in _get_dtype
#     state_dict = load_state_dict(
#         checkpoint_files[0], map_location="meta", weights_only=weights_only
#     )
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 532, in load_state_dict
#     check_torch_load_is_safe()
#     ~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/utils/import_utils.py", line 1632, in check_torch_load_is_safe
#     raise ValueError(
#     ...<4 lines>...
#     )
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/pipelines/base.py", line 311, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **fp32_kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 288, in _wrapper
#     return func(*args, **kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 5179, in from_pretrained
#     ) = cls._load_pretrained_model(
#         ~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         model,
#         ^^^^^^
#     ...<13 lines>...
#         weights_only=weights_only,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 5445, in _load_pretrained_model
#     load_state_dict(checkpoint_files[0], map_location="meta", weights_only=weights_only).keys()
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 532, in load_state_dict
#     check_torch_load_is_safe()
#     ~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/utils/import_utils.py", line 1632, in check_torch_load_is_safe
#     raise ValueError(
#     ...<4 lines>...
#     )
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434

# %%
from transformers import pipeline

translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
translator("Ce cours est produit par Hugging Face.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 from transformers import pipeline
# ----> 3 translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
#       4 translator("Ce cours est produit par Hugging Face.")
#
# File /opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/pipelines/__init__.py:1028, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1026 if isinstance(model, str) or framework is None:
#    1027     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# -> 1028     framework, model = infer_framework_load_model(
#    1029         adapter_path if adapter_path is not None else model,
#    1030         model_classes=model_classes,
#    1031         config=config,
#    1032         framework=framework,
#    1033         task=task,
#    1034         **hub_kwargs,
#    1035         **model_kwargs,
#    1036     )
#    1038 hub_kwargs["_commit_hash"] = model.config._commit_hash
#    1040 # Check which preprocessing classes the pipeline uses
#    1041 # None values indicate optional classes that the pipeline can run without, we don't raise errors if loading fails
#
# File /opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/pipelines/base.py:333, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     331         for class_name, trace in all_traceback.items():
#     332             error += f"while loading with {class_name}, an error is thrown:\n{trace}\n"
# --> 333         raise ValueError(
#     334             f"Could not load model {model} with any of the following classes: {class_tuple}. See the original errors:\n\n{error}\n"
#     335         )
#     337 if framework is None:
#     338     framework = infer_framework(model.__class__)
#
# ValueError: Could not load model Helsinki-NLP/opus-mt-fr-en with any of the following classes: (<class 'transformers.models.auto.modeling_auto.AutoModelForSeq2SeqLM'>, <class 'transformers.models.marian.modeling_marian.MarianMTModel'>). See the original errors:
#
# while loading with AutoModelForSeq2SeqLM, an error is thrown:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/pipelines/base.py", line 293, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/models/auto/auto_factory.py", line 604, in from_pretrained
#     return model_class.from_pretrained(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 288, in _wrapper
#     return func(*args, **kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 5097, in from_pretrained
#     config, dtype, dtype_orig = _get_dtype(
#                                 ~~~~~~~~~~^
#         cls, dtype, checkpoint_files, config, sharded_metadata, state_dict, weights_only
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 1358, in _get_dtype
#     state_dict = load_state_dict(
#         checkpoint_files[0], map_location="meta", weights_only=weights_only
#     )
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 532, in load_state_dict
#     check_torch_load_is_safe()
#     ~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/utils/import_utils.py", line 1632, in check_torch_load_is_safe
#     raise ValueError(
#     ...<4 lines>...
#     )
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/pipelines/base.py", line 311, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **fp32_kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/models/auto/auto_factory.py", line 604, in from_pretrained
#     return model_class.from_pretrained(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 288, in _wrapper
#     return func(*args, **kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 5179, in from_pretrained
#     ) = cls._load_pretrained_model(
#         ~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         model,
#         ^^^^^^
#     ...<13 lines>...
#         weights_only=weights_only,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 5445, in _load_pretrained_model
#     load_state_dict(checkpoint_files[0], map_location="meta", weights_only=weights_only).keys()
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 532, in load_state_dict
#     check_torch_load_is_safe()
#     ~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/utils/import_utils.py", line 1632, in check_torch_load_is_safe
#     raise ValueError(
#     ...<4 lines>...
#     )
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
#
# while loading with MarianMTModel, an error is thrown:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/pipelines/base.py", line 293, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 288, in _wrapper
#     return func(*args, **kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 5097, in from_pretrained
#     config, dtype, dtype_orig = _get_dtype(
#                                 ~~~~~~~~~~^
#         cls, dtype, checkpoint_files, config, sharded_metadata, state_dict, weights_only
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 1358, in _get_dtype
#     state_dict = load_state_dict(
#         checkpoint_files[0], map_location="meta", weights_only=weights_only
#     )
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 532, in load_state_dict
#     check_torch_load_is_safe()
#     ~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/utils/import_utils.py", line 1632, in check_torch_load_is_safe
#     raise ValueError(
#     ...<4 lines>...
#     )
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/pipelines/base.py", line 311, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **fp32_kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 288, in _wrapper
#     return func(*args, **kwargs)
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 5179, in from_pretrained
#     ) = cls._load_pretrained_model(
#         ~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         model,
#         ^^^^^^
#     ...<13 lines>...
#         weights_only=weights_only,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 5445, in _load_pretrained_model
#     load_state_dict(checkpoint_files[0], map_location="meta", weights_only=weights_only).keys()
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/modeling_utils.py", line 532, in load_state_dict
#     check_torch_load_is_safe()
#     ~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/miniconda3/envs/myproject/lib/python3.13/site-packages/transformers/utils/import_utils.py", line 1632, in check_torch_load_is_safe
#     raise ValueError(
#     ...<4 lines>...
#     )
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
